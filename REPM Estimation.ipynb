# %%
from urbansim.models.regression import RegressionModel

import os
import numpy as np
import pandas as pd
import orca
from urbansim.utils import misc

import orca
import datasources
import variables
import models
import utils

orca.run(['build_networks'])
orca.run(["neighborhood_vars"])
# Out:
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:298: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if cbook.is_string_like(arg):
# using seed 271828
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:765: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   not cbook.is_string_like(colors[0]):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:765: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   not cbook.is_string_like(colors[0]):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:765: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   not cbook.is_string_like(colors[0]):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:765: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   not cbook.is_string_like(colors[0]):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\colors.py:351: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cbook.is_string_like(arg) and cbook.iterable(arg):
# Bad key "patch.force_edgecolor" on line 33 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "lines.dashed_pattern" on line 18 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "boxplot.meanprops.markeredgecolor" on line 362 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.second" on line 228 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "ytick.major.right" on line 264 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.month" on line 224 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "scatter.marker" on line 338 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "ytick.minor.right" on line 266 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "ytick.major.left" on line 263 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "ytick.left" on line 251 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "xtick.minor.bottom" on line 249 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "axes.autolimit_mode" on line 213 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "hatch.color" on line 37 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "boxplot.meanprops.marker" on line 360 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.minute" on line 227 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "xtick.major.top" on line 246 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.day" on line 225 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "ytick.right" on line 252 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "xtick.bottom" on line 235 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.microsecond" on line 229 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "hist.bins" on line 40 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "lines.scale_dashes" on line 21 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "axes.titlepad" on line 177 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "_internal.classic_mode" on line 513 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.hour" on line 226 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "boxplot.meanprops.markerfacecolor" on line 361 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.year" on line 223 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\__init__.py:1069: UserWarning: Bad val "auto" on line #353
# 	"boxplot.flierprops.markerfacecolor: auto
# "
# 	in file "C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle"
# 	Key boxplot.flierprops.markerfacecolor: auto does not look like a color arg
#   (val, error_details, msg))
#
# Bad key "lines.dotted_pattern" on line 20 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "axes.formatter.offset_threshold" on line 200 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "xtick.minor.top" on line 248 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "ytick.minor.left" on line 265 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "lines.dashdot_pattern" on line 19 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "xtick.major.bottom" on line 247 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "boxplot.meanprops.markersize" on line 363 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "hatch.linewidth" on line 38 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "xtick.top" on line 234 in
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\urbansim\utils\yamlio.py:162: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   d = yaml.load(f)
# Running step 'build_networks'
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\pandana\network.py:82: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   nodes_df.astype('double').as_matrix(),
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\pandana\network.py:83: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   edges.as_matrix(),
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\pandana\network.py:85: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   .astype('double')
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\pandana\network.py:91: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   self.kdtree = KDTree(nodes_df.as_matrix())
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\pandana\network.py:371: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   distances, indexes = self.kdtree.query(xys.as_matrix())
# Time to execute step 'build_networks': 92.53 s
# Total time to execute iteration 1 with iteration value None: 92.55 s
# Running step 'neighborhood_vars'
# Computing accessibility variables
# Computing log_sum_residential_units
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\urbansim\utils\networks.py:18: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   cfg = yaml.load(open(misc.config(cfgname)))
# Removed 8 rows because they contain missing values
# Computing ave_lot_sqft
# Removed 8 rows because they contain missing values
# Computing log_sum_nonresidential_units
# Removed 8 rows because they contain missing values
# Computing population
# Computing households
# Computing midinc_hhs
# Computing lowinc_hhs
# Computing highinc_hhs
# Computing race_1_hhs
# Computing race_2_hhs
# Computing race_3_hhs
# Computing race_4_hhs
# Computing hhs_with_children
# Computing hhsize
# Computing ave_income
# Computing max_industrial_far
# Computing max_office_far
# Computing max_retail_far
# Computing max_medical_far
# Computing jobs
# Computing retail_jobs
# Computing node_r1500_sqft
# Computing residential
# Computing ave_nonres_sqft_price
# Removed 1 rows because they contain missing values
# Computing retail
# Computing office
# Removed 1 rows because they contain missing values
# Computing industrial
# Computing medical
# Computing quarter_mile_to_transit
# Computing log_15min_retail_jobs
# Computing log_15min_shopping_jobs
# Computing log_30min_retail_jobs
# Computing log_30min_shopping_jobs
# Computing accessibility variables
# Computing log_sum_30min_jobs
# Computing log_sum_45min_jobs
# Computing log_sum_60min_jobs
# Computing log_sum_10min_pop
# Computing log_sum_20min_pop
# Computing log_sum_15min_retail_jobs
# Computing log_sum_15min_shopping_jobs
# Computing log_sum_30min_retail_jobs
# Computing log_sum_30min_shopping_jobs
# Computing elem_school_perf
# Time to execute step 'neighborhood_vars': 63022.32 s
# Total time to execute iteration 1 with iteration value None: 63022.32 s

# %% [markdown]
# ## REPM Estimation Function

# %%
def estimate_repm(yaml_config):
    model = RegressionModel.from_yaml(str_or_buffer=misc.config(yaml_config))

    b = orca.get_table('buildings').to_frame(model.columns_used()).fillna(0)

    print model.fit(b)
    
    model.to_yaml(str_or_buffer=misc.config(yaml_config)) #  .replace('.yaml', '_new.yaml')

    return model.fit_parameters

# %% [markdown]
# ## REPM Configs

# %%
repm_configs=[]
path = './configs/repm/'
for filename in os.listdir(path):
    if not filename.endswith('.yaml'): continue
    repm_configs.append(os.path.join(path, filename).replace('./configs/', ''))
repm_configs.sort()
list(enumerate(repm_configs))
# Out:
# [(0, 'repm/nonres_repm11521.yaml'),
#  (1, 'repm/nonres_repm11522.yaml'),
#  (2, 'repm/nonres_repm11523.yaml'),
#  (3, 'repm/nonres_repm11525.yaml'),
#  (4, 'repm/nonres_repm11526.yaml'),
#  (5, 'repm/nonres_repm11531.yaml'),
#  (6, 'repm/nonres_repm11533.yaml'),
#  (7, 'repm/nonres_repm11541.yaml'),
#  (8, 'repm/nonres_repm11551.yaml'),
#  (9, 'repm/nonres_repm11571.yaml'),
#  (10, 'repm/nonres_repm12521.yaml'),
#  (11, 'repm/nonres_repm12522.yaml'),
#  (12, 'repm/nonres_repm12523.yaml'),
#  (13, 'repm/nonres_repm12525.yaml'),
#  (14, 'repm/nonres_repm12526.yaml'),
#  (15, 'repm/nonres_repm12531.yaml'),
#  (16, 'repm/nonres_repm12533.yaml'),
#  (17, 'repm/nonres_repm12541.yaml'),
#  (18, 'repm/nonres_repm12551.yaml'),
#  (19, 'repm/nonres_repm12571.yaml'),
#  (20, 'repm/nonres_repm14721.yaml'),
#  (21, 'repm/nonres_repm14722.yaml'),
#  (22, 'repm/nonres_repm14723.yaml'),
#  (23, 'repm/nonres_repm14725.yaml'),
#  (24, 'repm/nonres_repm14726.yaml'),
#  (25, 'repm/nonres_repm14731.yaml'),
#  (26, 'repm/nonres_repm14733.yaml'),
#  (27, 'repm/nonres_repm14741.yaml'),
#  (28, 'repm/nonres_repm14751.yaml'),
#  (29, 'repm/nonres_repm14771.yaml'),
#  (30, 'repm/nonres_repm16121.yaml'),
#  (31, 'repm/nonres_repm16122.yaml'),
#  (32, 'repm/nonres_repm16123.yaml'),
#  (33, 'repm/nonres_repm16125.yaml'),
#  (34, 'repm/nonres_repm16126.yaml'),
#  (35, 'repm/nonres_repm16131.yaml'),
#  (36, 'repm/nonres_repm16133.yaml'),
#  (37, 'repm/nonres_repm16141.yaml'),
#  (38, 'repm/nonres_repm16151.yaml'),
#  (39, 'repm/nonres_repm16171.yaml'),
#  (40, 'repm/nonres_repm24.yaml'),
#  (41, 'repm/nonres_repm32.yaml'),
#  (42, 'repm/nonres_repm321.yaml'),
#  (43, 'repm/nonres_repm322.yaml'),
#  (44, 'repm/nonres_repm323.yaml'),
#  (45, 'repm/nonres_repm325.yaml'),
#  (46, 'repm/nonres_repm326.yaml'),
#  (47, 'repm/nonres_repm331.yaml'),
#  (48, 'repm/nonres_repm333.yaml'),
#  (49, 'repm/nonres_repm341.yaml'),
#  (50, 'repm/nonres_repm351.yaml'),
#  (51, 'repm/nonres_repm371.yaml'),
#  (52, 'repm/nonres_repm42.yaml'),
#  (53, 'repm/nonres_repm43.yaml'),
#  (54, 'repm/nonres_repm52.yaml'),
#  (55, 'repm/nonres_repm521.yaml'),
#  (56, 'repm/nonres_repm522.yaml'),
#  (57, 'repm/nonres_repm523.yaml'),
#  (58, 'repm/nonres_repm525.yaml'),
#  (59, 'repm/nonres_repm526.yaml'),
#  (60, 'repm/nonres_repm53.yaml'),
#  (61, 'repm/nonres_repm531.yaml'),
#  (62, 'repm/nonres_repm533.yaml'),
#  (63, 'repm/nonres_repm541.yaml'),
#  (64, 'repm/nonres_repm551.yaml'),
#  (65, 'repm/nonres_repm61.yaml'),
#  (66, 'repm/nonres_repm62.yaml'),
#  (67, 'repm/nonres_repm9321.yaml'),
#  (68, 'repm/nonres_repm9322.yaml'),
#  (69, 'repm/nonres_repm9323.yaml'),
#  (70, 'repm/nonres_repm9325.yaml'),
#  (71, 'repm/nonres_repm9326.yaml'),
#  (72, 'repm/nonres_repm9331.yaml'),
#  (73, 'repm/nonres_repm9333.yaml'),
#  (74, 'repm/nonres_repm9341.yaml'),
#  (75, 'repm/nonres_repm9351.yaml'),
#  (76, 'repm/nonres_repm9371.yaml'),
#  (77, 'repm/nonres_repm9921.yaml'),
#  (78, 'repm/nonres_repm9922.yaml'),
#  (79, 'repm/nonres_repm9923.yaml'),
#  (80, 'repm/nonres_repm9925.yaml'),
#  (81, 'repm/nonres_repm9926.yaml'),
#  (82, 'repm/nonres_repm9931.yaml'),
#  (83, 'repm/nonres_repm9933.yaml'),
#  (84, 'repm/nonres_repm9941.yaml'),
#  (85, 'repm/nonres_repm9951.yaml'),
#  (86, 'repm/nonres_repm9971.yaml'),
#  (87, 'repm/res_repm11581.yaml'),
#  (88, 'repm/res_repm11582.yaml'),
#  (89, 'repm/res_repm11583.yaml'),
#  (90, 'repm/res_repm11584.yaml'),
#  (91, 'repm/res_repm12581.yaml'),
#  (92, 'repm/res_repm12582.yaml'),
#  (93, 'repm/res_repm12583.yaml'),
#  (94, 'repm/res_repm12584.yaml'),
#  (95, 'repm/res_repm14781.yaml'),
#  (96, 'repm/res_repm14782.yaml'),
#  (97, 'repm/res_repm14783.yaml'),
#  (98, 'repm/res_repm14784.yaml'),
#  (99, 'repm/res_repm16181.yaml'),
#  (100, 'repm/res_repm16182.yaml'),
#  (101, 'repm/res_repm16183.yaml'),
#  (102, 'repm/res_repm16184.yaml'),
#  (103, 'repm/res_repm381.yaml'),
#  (104, 'repm/res_repm382.yaml'),
#  (105, 'repm/res_repm383.yaml'),
#  (106, 'repm/res_repm384.yaml'),
#  (107, 'repm/res_repm581.yaml'),
#  (108, 'repm/res_repm582.yaml'),
#  (109, 'repm/res_repm583.yaml'),
#  (110, 'repm/res_repm9381.yaml'),
#  (111, 'repm/res_repm9382.yaml'),
#  (112, 'repm/res_repm9383.yaml'),
#  (113, 'repm/res_repm9384.yaml'),
#  (114, 'repm/res_repm9981.yaml'),
#  (115, 'repm/res_repm9982.yaml'),
#  (116, 'repm/res_repm9983.yaml'),
#  (117, 'repm/res_repm9984.yaml')]

# %% [markdown]
# ## Estimate a particular REPM submodel

# %%
semcog_hdfstore = pd.HDFStore("data/run4032_school_v2_baseyear.h5", mode="r")
orca.add_injectable("store", semcog_hdfstore)

# %%
@orca.table('jobs') 
def jobs(store): 
    df = store['jobs']
    return df

@orca.table('buildings') 
def jobs(store): 
    df = store['buildings']
    return df

@orca.table('parcels') 
def jobs(store): 
    df = store['parcels']
    return df

# %%
from urbansim.utils import misc

def get_nearest(net, dfpoi, cats, searchdis, numpoi, maxdis):
    net.set_pois(''.join(cats), dfpoi['point_x'], dfpoi['point_y'])
    return net.nearest_pois(searchdis, ''.join(cats), num_pois=numpoi, max_distance=maxdis)[1]


@orca.column('nodes_drv', cache=True, cache_scope='iteration')
def drv_nearest_hospital(poi):
    cats = ['Hospitals']
    t = poi.to_frame()[poi.category.isin(cats)]
    return get_nearest(orca.get_injectable('net_drv'), t, cats, 15, 1, 16)

# %%
net = orca.get_injectable('net_walk')

# %%
estimate_repm(repm_configs[1])
# Out:
# Disaggregating logsum_job_low_income to buildings from zones
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-38bcdb725fd7> in <module>()
# ----> 1 estimate_repm(repm_configs[1])
#
# <ipython-input-2-ba9bdafc3afe> in estimate_repm(yaml_config)
#       2     model = RegressionModel.from_yaml(str_or_buffer=misc.config(yaml_config))
#       3
# ----> 4     b = orca.get_table('buildings').to_frame(model.columns_used()).fillna(0)
#       5
#       6     print model.fit(b)
#
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\orca\orca.pyc in to_frame(self, columns)
#     233                             name, self.name),
#     234                         logger):
# --> 235                     df[name] = col()
#     236
#     237         return df
#
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\orca\orca.pyc in __call__(self)
#     637             kwargs = _collect_variables(names=self._argspec.args,
#     638                                         expressions=self._argspec.defaults)
# --> 639             col = self._func(**kwargs)
#     640
#     641         if self.cache:
#
# C:\Users\Juan\Documents\GitHub\semcog_urbansim\semcog_urbansim\variables\variables_building.pyc in walk_nearest_urgentcare(buildings, parcels)
#     233 @orca.column('buildings', cache=True, cache_scope='iteration')
#     234 def walk_nearest_urgentcare(buildings, parcels):
# --> 235     return misc.reindex(parcels.walk_nearest_urgentcare, buildings.parcel_id)
#     236
#     237
#
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\orca\orca.pyc in __getattr__(self, key)
#     291
#     292     def __getattr__(self, key):
# --> 293         return self.get_column(key)
#     294
#     295     def column_type(self, column_name):
#
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\orca\orca.pyc in get_column(self, column_name)
#     279                             column_name, self.name),
#     280                         logger):
# --> 281                     column = extra_cols[column_name]()
#     282             else:
#     283                 column = self.local[column_name]
#
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\orca\orca.pyc in __call__(self)
#     637             kwargs = _collect_variables(names=self._argspec.args,
#     638                                         expressions=self._argspec.defaults)
# --> 639             col = self._func(**kwargs)
#     640
#     641         if self.cache:
#
# C:\Users\Juan\Documents\GitHub\semcog_urbansim\semcog_urbansim\variables\variables_parcel.pyc in walk_nearest_urgentcare(parcels, nodes_walk)
#     280         # if nodes isn't generated yet
#     281         return pd.Series(index=parcels.index)
# --> 282     return misc.reindex(nodes_walk.walk_nearest_urgentcare, parcels.nodeid_walk)
#     283
#     284
#
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\orca\orca.pyc in __getattr__(self, key)
#     291
#     292     def __getattr__(self, key):
# --> 293         return self.get_column(key)
#     294
#     295     def column_type(self, column_name):
#
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\orca\orca.pyc in get_column(self, column_name)
#     279                             column_name, self.name),
#     280                         logger):
# --> 281                     column = extra_cols[column_name]()
#     282             else:
#     283                 column = self.local[column_name]
#
# C:\Users\Juan\Anaconda3\envs\semcog_py2\lib\site-packages\orca\orca.pyc in __call__(self)
#     637             kwargs = _collect_variables(names=self._argspec.args,
#     638                                         expressions=self._argspec.defaults)
# --> 639             col = self._func(**kwargs)
#     640
#     641         if self.cache:
#
# C:\Users\Juan\Documents\GitHub\semcog_urbansim\semcog_urbansim\variables\variables_access.pyc in walk_nearest_urgentcare(poi)
#     125     cats = ['UrgentCare']
#     126     t = poi.to_frame()[poi.category.isin(cats)]
# --> 127     return get_nearest(orca.get_injectable('net_walk'), t, cats, 7920, 1, 7921)
#     128
#     129
#
# C:\Users\Juan\Documents\GitHub\semcog_urbansim\semcog_urbansim\variables\variables_access.pyc in get_nearest(net, dfpoi, cats, searchdis, numpoi, maxdis)
#      35
#      36 def get_nearest(net, dfpoi, cats, searchdis, numpoi, maxdis):
# ---> 37     net.set_pois(''.join(cats), dfpoi['point_x'], dfpoi['point_y'])
#      38     return net.nearest_pois(searchdis, ''.join(cats), num_pois=numpoi, max_distance=maxdis)[1]
#      39
#
# TypeError: set_pois() takes exactly 6 arguments (4 given)

# %%
for i, lcm in list(enumerate(repm_configs))[:]:
    print 
    print i, lcm
    estimate_repm(lcm)
# Out:
# 0 repm/nonres_repm11521.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eae60d0>
#
# 1 repm/nonres_repm11522.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f6643d56e90>
#
# 2 repm/nonres_repm11523.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f66ab5e7710>
#
# 3 repm/nonres_repm11525.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eabd2d0>
#
# 4 repm/nonres_repm11526.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb21ed0>
#
# 5 repm/nonres_repm11531.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb21390>
#
# 6 repm/nonres_repm11533.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eabded0>
#
# 7 repm/nonres_repm11541.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea9a450>
#
# 8 repm/nonres_repm11551.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea9a290>
#
# 9 repm/nonres_repm11571.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea97810>
#
# 10 repm/nonres_repm12521.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea9a350>
#
# 11 repm/nonres_repm12522.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f664045da50>
#
# 12 repm/nonres_repm12523.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea90590>
#
# 13 repm/nonres_repm12525.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eadb790>
#
# 14 repm/nonres_repm12526.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eadb0d0>
#
# 15 repm/nonres_repm12531.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea97850>
#
# 16 repm/nonres_repm12533.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea9a550>
#
# 17 repm/nonres_repm12541.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea90990>
#
# 18 repm/nonres_repm12551.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f66403a8650>
#
# 19 repm/nonres_repm12571.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea90d90>
#
# 20 repm/nonres_repm14721.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eadb5d0>
#
# 21 repm/nonres_repm14722.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eaf9490>
#
# 22 repm/nonres_repm14723.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eaa8a50>
#
# 23 repm/nonres_repm14725.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eabd5d0>
#
# 24 repm/nonres_repm14726.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eaac290>
#
# 25 repm/nonres_repm14731.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea9a810>
#
# 26 repm/nonres_repm14733.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb30450>
#
# 27 repm/nonres_repm14741.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea97b50>
#
# 28 repm/nonres_repm14751.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb1c210>
#
# 29 repm/nonres_repm14771.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eaa8090>
#
# 30 repm/nonres_repm16121.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea97690>
#
# 31 repm/nonres_repm16122.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb1cd50>
#
# 32 repm/nonres_repm16123.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eaa85d0>
#
# 33 repm/nonres_repm16125.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea970d0>
#
# 34 repm/nonres_repm16126.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eaa8d10>
#
# 35 repm/nonres_repm16131.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb21990>
#
# 36 repm/nonres_repm16133.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb21190>
#
# 37 repm/nonres_repm16141.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eabd3d0>
#
# 38 repm/nonres_repm16151.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eae6fd0>
#
# 39 repm/nonres_repm16171.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eadbb50>
#
# 40 repm/nonres_repm24.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea44cd0>
#
# 41 repm/nonres_repm32.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eadb550>
#
# 42 repm/nonres_repm321.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f66403dedd0>
#
# 43 repm/nonres_repm322.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eabdc50>
#
# 44 repm/nonres_repm323.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eabdc90>
#
# 45 repm/nonres_repm325.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f66403fb550>
#
# 46 repm/nonres_repm326.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eadb590>
#
# 47 repm/nonres_repm331.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea44990>
#
# 48 repm/nonres_repm333.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea44950>
#
# 49 repm/nonres_repm341.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb30e10>
#
# 50 repm/nonres_repm351.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb219d0>
#
# 51 repm/nonres_repm371.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f664045de50>
#
# 52 repm/nonres_repm42.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eabd110>
#
# 53 repm/nonres_repm43.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eaf9f90>
#
# 54 repm/nonres_repm52.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f6640343cd0>
#
# 55 repm/nonres_repm521.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb1c410>
#
# 56 repm/nonres_repm522.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb21f50>
#
# 57 repm/nonres_repm523.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f66403a96d0>
#
# 58 repm/nonres_repm525.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eadb290>
#
# 59 repm/nonres_repm526.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea44a10>
#
# 60 repm/nonres_repm53.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eabd050>
#
# 61 repm/nonres_repm531.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f66403a8ed0>
#
# 62 repm/nonres_repm533.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f66403a9fd0>
#
# 63 repm/nonres_repm541.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f6640493b10>
#
# 64 repm/nonres_repm551.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb21450>
#
# 65 repm/nonres_repm61.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f6640436e10>
#
# 66 repm/nonres_repm62.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f664045d2d0>
#
# 67 repm/nonres_repm9321.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb30c90>
#
# 68 repm/nonres_repm9322.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eadb150>
#
# 69 repm/nonres_repm9323.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eabdd50>
#
# 70 repm/nonres_repm9325.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f664034c950>
#
# 71 repm/nonres_repm9326.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f664045d710>
#
# 72 repm/nonres_repm9331.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eadbd90>
#
# 73 repm/nonres_repm9333.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea44c90>
#
# 74 repm/nonres_repm9341.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb1c710>
#
# 75 repm/nonres_repm9351.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eae66d0>
#
# 76 repm/nonres_repm9371.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea44dd0>
#
# 77 repm/nonres_repm9921.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea44950>
#
# 78 repm/nonres_repm9922.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb1cd50>
#
# 79 repm/nonres_repm9923.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f664034c750>
#
# 80 repm/nonres_repm9925.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f664034c350>
#
# 81 repm/nonres_repm9926.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f6640343790>
#
# 82 repm/nonres_repm9931.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eabdbd0>
#
# 83 repm/nonres_repm9933.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f6643cddb10>
#
# 84 repm/nonres_repm9941.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f664045da90>
#
# 85 repm/nonres_repm9951.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eaf9c10>
#
# 86 repm/nonres_repm9971.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb30990>
#
# 87 repm/res_repm11581.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f6640343ad0>
#
# 88 repm/res_repm11582.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f66ec5d6210>
#
# 89 repm/res_repm11583.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f6640349d50>
#
# 90 repm/res_repm11584.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f66403de150>
#
# 91 repm/res_repm12581.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f66403436d0>
#
# 92 repm/res_repm12582.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eabdad0>
#
# 93 repm/res_repm12583.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f664034c050>
#
# 94 repm/res_repm12584.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f6640349f50>
#
# 95 repm/res_repm14781.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb1cb10>
#
# 96 repm/res_repm14782.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f664045df10>
#
# 97 repm/res_repm14783.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eaee490>
#
# 98 repm/res_repm14784.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f66403fba50>
#
# 99 repm/res_repm16181.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f66403fbad0>
#
# 100 repm/res_repm16182.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eaf9490>
#
# 101 repm/res_repm16183.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eabc1d0>
#
# 102 repm/res_repm16184.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f6640349bd0>
#
# 103 repm/res_repm381.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f6643cdd410>
#
# 104 repm/res_repm382.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb215d0>
#
# 105 repm/res_repm383.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f66403fb550>
#
# 106 repm/res_repm384.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f66ab5cdfd0>
#
# 107 repm/res_repm581.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f6640493c10>
#
# 108 repm/res_repm582.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eaae250>
#
# 109 repm/res_repm583.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea44910>
#
# 110 repm/res_repm9381.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f6640436dd0>
#
# 111 repm/res_repm9382.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb1ce50>
#
# 112 repm/res_repm9383.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eadb150>
#
# 113 repm/res_repm9384.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb219d0>
#
# 114 repm/res_repm9981.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663ea87210>
#
# 115 repm/res_repm9982.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f6640349ed0>
#
# 116 repm/res_repm9983.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eaeea90>
#
# 117 repm/res_repm9984.yaml
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x7f663eb30f10>
